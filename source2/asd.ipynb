# %%
import pandas as pd

# %%
weather_data = pd.read_csv('..\data_weather\climate_data.csv')
weather_data.head()
# Out:
#          Date  Average temperature (°F)  Average humidity (%)  \
# 0  2009-01-01                      37.8                  35.0
# 1  2009-01-02                      43.2                  32.0
# 2  2009-01-03                      25.7                  60.0
# 3  2009-01-04                       9.3                  67.0
# 4  2009-01-05                      23.5                  30.0
#
#    Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                   12.7                    29.7                     26.4
# 1                   14.7                    29.5                     12.8
# 2                   12.7                    29.7                      8.3
# 3                    0.1                    30.4                      2.9
# 4                   -5.3                    29.9                     16.7
#
#    Average gustspeed (mph)  Average direction (°deg)  Rainfall for month (in)  \
# ...

# %%
dates = weather_data.Date
dates.groupby
# Out:
# <bound method Series.groupby of 0       2009-01-01
# 1       2009-01-02
# 2       2009-01-03
# 3       2009-01-04
# 4       2009-01-05
#            ...
# 3897    2020-07-24
# 3898    2020-07-25
# 3899    2020-07-26
# 3900    2020-07-27
# 3901    2020-07-28
# Name: Date, Length: 3902, dtype: object>

# %%
import boto3

s3 = boto3.resource('s3')

# %%
s3.create_bucket(Bucket='mybucket')
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8484/3948958764.py in <module>
# ----> 1 s3.create_bucket(Bucket='mybucket')
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\boto3\resources\factory.py in do_action(self, *args, **kwargs)
#     518             # instance via ``self``.
#     519             def do_action(self, *args, **kwargs):
# --> 520                 response = action(self, *args, **kwargs)
#     521
#     522                 if hasattr(self, 'load'):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\boto3\resources\action.py in __call__(self, parent, *args, **kwargs)
#      81                      operation_name, params)
#      82
# ...
