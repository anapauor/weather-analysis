# %%
import pandas as pd

# %%
weather_data = pd.read_csv('..\data_weather\climate_data.csv') # loading data into dataframe
weather_data.head()
# Out:
#          Date  Average temperature (°F)  Average humidity (%)  \
# 0  2009-01-01                      37.8                  35.0
# 1  2009-01-02                      43.2                  32.0
# 2  2009-01-03                      25.7                  60.0
# 3  2009-01-04                       9.3                  67.0
# 4  2009-01-05                      23.5                  30.0
#
#    Average dewpoint (°F)  Average barometer (in)  Average windspeed (mph)  \
# 0                   12.7                    29.7                     26.4
# 1                   14.7                    29.5                     12.8
# 2                   12.7                    29.7                      8.3
# 3                    0.1                    30.4                      2.9
# 4                   -5.3                    29.9                     16.7
#
#    Average gustspeed (mph)  Average direction (°deg)  Rainfall for month (in)  \
# ...

# %%
from decimal import Decimal
import json
import boto3

# %%
weather_data = weather_data.rename(columns={'Date': 'date'}) # transforming column names for matching with Dtnadb tamble rowkey

dic_data = weather_data.to_dict('records') # Convert dataframe into a list o json object

ddb_data = json.loads(json.dumps(dic_data), parse_float=Decimal) # transforming float into decimal for using boto3 put_item()

# %%
import boto3
s3 = boto3.resource('s3')

dynamodb = boto3.resource('dynamodb')
table = dynamodb.Table('weather_data')
for element in ddb_data:
    #print(element)
    table.put_item(Item=element)

# %%
import boto3
from botocore.config import Config # aws credentials configured previously in the CLI


location = {'LocationConstraint': 'sa-east-1'}
s3.create_bucket(Bucket='mybucketapor', CreateBucketConfiguration=location)
# Out:
# s3.Bucket(name='mybucketapor')

# %%
from pprint import pprint
import boto3


def put_movie(title, year, plot, rating, dynamodb=None):
    if not dynamodb:
        dynamodb = boto3.resource('dynamodb')

    table = dynamodb.Table('Movies')
    response = table.put_item(
       Item={
            'year': year,
            'title': title,
            'info': {
                'plot': plot,
                'rating': rating
            }
        }
    )
    return response

# %%
movie_resp = put_movie("The Big New Movie", 2015,
                           "Nothing happens at all.", 0)
print("Put movie succeeded:")
pprint(movie_resp, sort_dicts=False)
# Out:
# Put movie succeeded:
# {'ResponseMetadata': {'RequestId': 'KTIMBEFGGVCOKVQCQ82IO6IHI3VV4KQNSO5AEMVJF66Q9ASUAAJG',
#                       'HTTPStatusCode': 200,
#                       'HTTPHeaders': {'server': 'Server',
#                                       'date': 'Sun, 26 Dec 2021 16:58:53 GMT',
#                                       'content-type': 'application/x-amz-json-1.0',
#                                       'content-length': '2',
#                                       'connection': 'keep-alive',
#                                       'x-amzn-requestid': 'KTIMBEFGGVCOKVQCQ82IO6IHI3VV4KQNSO5AEMVJF66Q9ASUAAJG',
#                                       'x-amz-crc32': '2745614147'},
#                       'RetryAttempts': 0}}

# %%
def create_json(df):
    dic = {}
    for row, col in zip(df):
        col[row]=row
# Out:
#   File "C:\Users\Milton\AppData\Local\Temp/ipykernel_14656/2867352104.py", line 3
#     for row, col in zip(df):
#                             ^
# IndentationError: expected an indented block
